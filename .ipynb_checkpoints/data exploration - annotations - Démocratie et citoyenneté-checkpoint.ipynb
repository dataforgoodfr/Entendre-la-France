# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import Counter
import matplotlib.pylab as plt

# %%
get_ipython().config.get('IPKernelApp', {})['parent_appname'] = ""

# %%
# Import des questions

# %%
answers_grand_debat_raw = pd.read_csv('raw/DEMOCRATIE_ET_CITOYENNETE.csv', encoding="utf-8").drop_duplicates(keep=False)
answers_annotees = pd.read_csv('raw/actions.csv', encoding="utf-8").rename(columns={'Contribution': 'reference'})
answers_grand_debat_raw = pd.merge(answers_annotees, answers_grand_debat_raw, on='reference')

# %%
answers_annotees.head()
# Out:
#    Debat reference  Question                                Categorie  \
# 0      1       1-8       107  Sans réponse / Hors sujet / Inclassable
# 1      1       1-8       107  Sans réponse / Hors sujet / Inclassable
# 2      1       1-8       107  Sans réponse / Hors sujet / Inclassable
# 3      1      1-15       107               Président de la République
# 4      1      1-15       107               Président de la République
#
#    Annotateur     Poids
# 0         513  1.451059
# 1           1  1.451059
# 2         406  1.451059
# 3         406  1.543980
# 4           1  1.543980

# %%
answers_grand_debat_raw['empty_columns'] = answers_grand_debat_raw.isna().sum(axis = 1)
answers_grand_debat_raw_test = answers_grand_debat_raw[answers_grand_debat_raw['reference'] == '1-20']

# %%
# Liste des réponses QCM à enlever du corpus

# %%
answers_grand_debat_raw_test[answers_grand_debat_raw_test.columns.difference(['Debat', 'id', 'Poids', 'trashed', 'trashedStatus', 'updatedAt', 'authorId'])]
# Out:
#     Annotateur           Categorie  \
# 12           1  Maires et communes
# 13         513  Maires et communes
# 14           2  Maires et communes
#
#    QUXVlc3Rpb246MTA3 - En qui faites-vous le plus confiance pour vous faire représenter dans la société et pourquoi ?  \
# 12                                              maire
# 13                                              maire
# 14                                              maire
#
#    QUXVlc3Rpb246MTA4 - En dehors des élus politiques, faut-il donner un rôle plus important aux associations et aux organisations syndicales et professionnelles ?  \
# 12                                                Oui
# 13                                                Oui
# 14                                                Oui
#
#    QUXVlc3Rpb246MTA5 - Si oui, à quel type d'associations ou d'organisations ? Et avec quel rôle ?  \
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    QUXVlc3Rpb246MTE0 - Pensez-vous qu'il serait souhaitable de réduire le nombre d'élus (hors députés et sénateurs) ?  \
# 12                                                Non
# 13                                                Non
# 14                                                Non
#
#    QUXVlc3Rpb246MTE1 - Si oui, lesquels ?  \
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#    QUXVlc3Rpb246MTE2 - Que pensez-vous de la participation des citoyens aux élections et comment les inciter à y participer davantage ?  \
# 12     que les candidats soient crédibles et honnêtes
# 13     que les candidats soient crédibles et honnêtes
# 14     que les candidats soient crédibles et honnêtes
#
#    QUXVlc3Rpb246MTE3 - Faut-il prendre en compte le vote blanc ?  \
# 12                                                Oui
# 13                                                Oui
# 14                                                Oui
#
#    QUXVlc3Rpb246MTE4 - Si oui, de quelle manière ?  ...  \
# 12                            en le comptabilisant  ...
# 13                            en le comptabilisant  ...
# 14                            en le comptabilisant  ...
#
#    QUXVlc3Rpb246MTQy - En matière d'immigration, une fois nos obligations d'asile remplies, souhaitez-vous que nous puissions nous fixer des objectifs annuels définis par le Parlement ?  \
# 12                           expulsion ou arrestation
# 13                           expulsion ou arrestation
# 14                           expulsion ou arrestation
#
#    QUXVlc3Rpb246MTQz - Que proposez-vous afin de répondre à ce défi qui va durer ?  \
# 12                           expulsion ou arrestation
# 13                           expulsion ou arrestation
# 14                           expulsion ou arrestation
#
#    Question           authorType authorZipCode            createdAt  \
# 12      107  Citoyen / Citoyenne         43100  2019-01-22 09:55:09
# 13      107  Citoyen / Citoyenne         43100  2019-01-22 09:55:09
# 14      107  Citoyen / Citoyenne         43100  2019-01-22 09:55:09
#
#    empty_columns          publishedAt reference                   title
# 12             8  2019-01-22 09:55:09      1-20  suppression du 80 km/h
# 13             8  2019-01-22 09:55:09      1-20  suppression du 80 km/h
# 14             8  2019-01-22 09:55:09      1-20  suppression du 80 km/h
#
# [3 rows x 47 columns]

# %%
answers_grand_debat_raw[answers_grand_debat_raw['Question'] ].unique()
# Out:
# array([107, 113, 110, 118, 127])

# %%
question_titles = [
    "QUXVlc3Rpb246MTA3 - En qui faites-vous le plus confiance pour vous faire représenter dans la société et pourquoi ?",
    "QUXVlc3Rpb246MTA4 - En dehors des élus politiques, faut-il donner un rôle plus important aux associations et aux organisations syndicales et professionnelles ?",
    "QUXVlc3Rpb246MTA5 - Si oui, à quel type d'associations ou d'organisations ? Et avec quel rôle ?",
    "QUXVlc3Rpb246MTEw - Que faudrait-il faire pour renouer le lien entre les citoyens et les élus qui les représentent ?",
    "QUXVlc3Rpb246MTEx - Le non-cumul des mandats instauré en 2017 pour les parlementaires (députés et sénateurs) est :",
    "QUXVlc3Rpb246MTEy - Pourquoi ?",
    "QUXVlc3Rpb246MTEz - Que faudrait-il faire pour mieux représenter les différentes sensibilités politiques ?",
    "QUXVlc3Rpb246MTE0 - Pensez-vous qu'il serait souhaitable de réduire le nombre d'élus (hors députés et sénateurs) ?",
    "QUXVlc3Rpb246MTE1 - Si oui, lesquels ?",
    "QUXVlc3Rpb246MTE2 - Que pensez-vous de la participation des citoyens aux élections et comment les inciter à y participer davantage ?",
    "QUXVlc3Rpb246MTE3 - Faut-il prendre en compte le vote blanc ?",
    "QUXVlc3Rpb246MTE4 - Si oui, de quelle manière ?",
    "QUXVlc3Rpb246MTE5 - Que faudrait-il faire aujourd'hui pour mieux associer les citoyens aux grandes orientations et à la décision publique ? Comment mettre en place une démocratie plus participative ?",
    "QUXVlc3Rpb246MTIw - Faut-il faciliter le déclenchement du référendum d'initiative partagée (le RIP est organisé à l'initiative de membres du Parlement soutenu par une partie du corps électoral) qui est applicable depuis 2015 ?",
    "QUXVlc3Rpb246MTIx - Si oui, comment ?",
    "QUXVlc3Rpb246MTIy - Que faudrait-il faire pour consulter plus directement les citoyens sur l'utilisation de l'argent public, par l'Etat et les collectivités ?",
    "QUXVlc3Rpb246MTIz - Quel rôle nos assemblées, dont le Sénat et le Conseil économique, social et environnemental, doivent-elles jouer pour représenter nos territoires et la société civile ?",
    "QUXVlc3Rpb246MTI0 - Faut-il les transformer ?",
    "QUXVlc3Rpb246MTI1 - Si oui, comment ?",
    "QUXVlc3Rpb246MTI3 - Que proposez-vous pour renforcer les principes de la laïcité dans le rapport entre l'Etat et les religions de notre pays ?",
    "QUXVlc3Rpb246MTI4 - Comment garantir le respect par tous de la compréhension réciproque et des valeurs intangibles de la République ?",
    "QUXVlc3Rpb246MTI5 - Que faudrait-il faire aujourd'hui pour renforcer l'engagement citoyen dans la société ?",
    "QUXVlc3Rpb246MTMw - Quels sont les comportements civiques qu'il faut promouvoir dans notre vie quotidienne ou collective ?",
    "QUXVlc3Rpb246MTMx - Que faudrait-il faire pour favoriser le développement de ces comportements civiques et par quels engagements concrets chacun peut-il y participer ?",
    "QUXVlc3Rpb246MTMy - Que faudrait-il faire pour valoriser l'engagement citoyen dans les parcours de vie, dans les relations avec l'administration et les pouvoirs publics ?",
    "QUXVlc3Rpb246MTMz - Quelles sont les incivilités les plus pénibles dans la vie quotidienne et que faudrait-il faire pour lutter contre ces incivilités ?",
    "QUXVlc3Rpb246MTM0 - Que peuvent et doivent faire les pouvoirs publics pour répondre aux incivilités ?",
    "QUXVlc3Rpb246MTM1 - Quel pourrait être le rôle de chacun pour faire reculer les incivilités dans la société ?",
    "QUXVlc3Rpb246MTM2 - Quelles sont les discriminations les plus répandues dont vous êtes témoin ou victime ?",
    "QUXVlc3Rpb246MTM3 - Que faudrait-il faire pour lutter contre ces discriminations et construire une société plus solidaire et plus tolérante ?",
    "QUXVlc3Rpb246MTM4 - Pensez-vous qu'il faille instaurer des contreparties aux différentes allocations de solidarité ?",
    "QUXVlc3Rpb246MTM5 - Si oui, lesquelles ?",
    "QUXVlc3Rpb246MTQx - Que pensez-vous de la situation de l'immigration en France aujourd'hui et de la politique migratoire ? Quelles sont, selon vous, les critères à mettre en place pour définir la politique migratoire ?",
    "QUXVlc3Rpb246MTQy - En matière d'immigration, une fois nos obligations d'asile remplies, souhaitez-vous que nous puissions nous fixer des objectifs annuels définis par le Parlement ?",
    "QUXVlc3Rpb246MTQz - Que proposez-vous afin de répondre à ce défi qui va durer ?",
    "QUXVlc3Rpb246MTQ0 - Quelles sont, selon vous, les modalités d'intégration les plus efficaces et les plus justes à mettre en place aujourd'hui dans la société ?",
    "QUXVlc3Rpb246MTQ1 - Y a-t-il d'autres points sur la démocratie et la citoyenneté sur lesquels vous souhaiteriez vous exprimer ?"
]
question_title = ["QUXVlc3Rpb246MTI3 - Que proposez-vous pour renforcer les principes de la laïcité dans le rapport entre l'Etat et les religions de notre pays ?"]
answers_grand_debat_raw['corpus'] = answers_grand_debat_raw[question_title].fillna('').astype(str).apply(lambda x: ' '.join(x), axis=1)
answers_grand_debat = answers_grand_debat_raw[answers_grand_debat_raw["QUXVlc3Rpb246MTI3 - Que proposez-vous pour renforcer les principes de la laïcité dans le rapport entre l'Etat et les religions de notre pays ?"].notnull()].drop(['title'] + question_titles,axis=1)

# %%
answers_grand_debat = answers_grand_debat[answers_grand_debat['Question'] == 127].drop_duplicates(keep=False)

# %%
allowed_categories_tuples = Counter(answers_grand_debat['Categorie']).most_common(20)
allowed_categories_tuples
# Out:
# [('Y Rien', 1113),
#  ('Sans réponse / Hors sujet / Inclassable', 836),
#  ('Application loi 1905', 647),
#  ('Z Autres', 403),
#  ('Aucun signe ostentatoire (croix, voile, kippa...)', 283),
#  ('Séparation stricte Etat-religions', 243),
#  ('Loi de la République avant celles de la religion', 240),
#  ('Même traitement pour toutes les religions', 237),
#  ('Redonner un aspect privé à la religion', 232),
#  ("Plus d'éducation", 221),
#  ('Condamnation des atteintes à la laïcité', 158),
#  ('Lutte contre extrémismes', 142),
#  ("Aucun financement par l'Etat", 142),
#  ('Préserver les coutumes françaises', 123),
#  ('Garantir la liberté de culte', 102),
#  ('Plus de tolérance', 97),
#  ('Réduire financements étrangers', 94),
#  ('Stop prosélytisme', 73),
#  ('Statut des écoles religieuses', 70),
#  ('Plus de dialogue', 64)]

# %%
removed_categories = ['Z Autres', 'Sans réponse / Hors sujet / Inclassable', 'Y Rien']
answers_grand_debat_light = answers_grand_debat[['reference', 'Categorie', 'corpus', 'Question', 'Annotateur']][~answers_grand_debat['Categorie'].isin(removed_categories)]

# %%
allowed_categories_tuples = Counter(answers_grand_debat_light['Categorie']).most_common(20)
allowed_categories = [element[0] for element in allowed_categories_tuples]
answers_grand_debat_light = answers_grand_debat_light[answers_grand_debat_light['Categorie'].isin(allowed_categories)]

# %%
print(allowed_categories)
print(len(allowed_categories))
print(len(answers_grand_debat_light))
# Out:
# ['Application loi 1905', 'Aucun signe ostentatoire (croix, voile, kippa...)', 'Séparation stricte Etat-religions', 'Loi de la République avant celles de la religion', 'Même traitement pour toutes les religions', 'Redonner un aspect privé à la religion', "Plus d'éducation", 'Condamnation des atteintes à la laïcité', 'Lutte contre extrémismes', "Aucun financement par l'Etat", 'Préserver les coutumes françaises', 'Garantir la liberté de culte', 'Plus de tolérance', 'Réduire financements étrangers', 'Stop prosélytisme', 'Statut des écoles religieuses', 'Plus de dialogue', "Pas d'imposition des valeurs", 'Encadrer formation imams', 'Pas de laïcité extrême']
# 20
# 3329

# %%
answers_grand_debat_light.head()
# Out:
#    reference             Categorie                     corpus  Question  \
# 63      1-72  Application loi 1905  respect de la loi de 1905       127
# 64      1-72  Application loi 1905  respect de la loi de 1905       127
# 65      1-72  Application loi 1905  respect de la loi de 1905       127
# 69      1-78  Application loi 1905      La loi de 1905 suffit       127
# 70      1-78  Application loi 1905      La loi de 1905 suffit       127
#
#     Annotateur
# 63         529
# 64           2
# 65         513
# 69         529
# 70         406

# %%
answers_grand_debat_count = pd.DataFrame({'count' : answers_grand_debat_light.groupby( ['reference', 'Categorie', 'corpus', 'Question'] ).apply(lambda x: x.Annotateur.nunique())}).reset_index()
answers_grand_debat_count.head()
# Out:
#   reference                                         Categorie  \
# 0   1-10092                      Aucun financement par l'Etat
# 1   1-10092                      Garantir la liberté de culte
# 2   1-10092  Loi de la République avant celles de la religion
# 3   1-10092                          Lutte contre extrémismes
# 4   1-10092         Même traitement pour toutes les religions
#
#                                               corpus  Question  count
# 0  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      1
# 1  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      1
# 2  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      5
# 3  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      2
# 4  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      1

# %%
answers_grand_debat_input = answers_grand_debat_count.rename(columns={'reference': 'contribution', 'Categorie': 'tag', 'Question': 'question'})
answers_grand_debat_input.to_csv('preprocessed/reponses_annotees_multilabel.csv', sep='\t', encoding='utf-8')

# %%
answers_grand_debat_input.head()
# Out:
#   contribution                                               tag  \
# 0      1-10092                      Aucun financement par l'Etat
# 1      1-10092                      Garantir la liberté de culte
# 2      1-10092  Loi de la République avant celles de la religion
# 3      1-10092                          Lutte contre extrémismes
# 4      1-10092         Même traitement pour toutes les religions
#
#                                               corpus  question  count
# 0  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      1
# 1  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      1
# 2  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      5
# 3  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      2
# 4  1/. LA FERMETÉ; la voix du peuple est supérieu...       127      1
