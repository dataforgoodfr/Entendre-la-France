# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import Counter
import matplotlib.pylab as plt

# %%
get_ipython().config.get('IPKernelApp', {})['parent_appname'] = ""

# %%
# Import des questions

# %%
answers_grand_debat_LTE_raw = pd.read_csv('raw/large_datasets_ELF/LA_TRANSITION_ECOLOGIQUE.csv', encoding="utf-8").drop_duplicates(keep=False)
answers_grand_debat_FDP_raw = pd.read_csv('raw/large_datasets_ELF/LA_FISCALITE_ET_LES_DEPENSES_PUBLIQUES.csv', encoding="utf-8").drop_duplicates(keep=False)
answers_grand_debat_ORG_raw = pd.read_csv('raw/large_datasets_ELF/ORGANISATION_DE_LETAT_ET_DES_SERVICES_PUBLICS.csv', encoding="utf-8").drop_duplicates(keep=False)
answers_grand_debat_DEC_raw = pd.read_csv('raw/large_datasets_ELF/DEMOCRATIE_ET_CITOYENNETE.csv', encoding="utf-8").drop_duplicates(keep=False)

# %%
answers_grand_debat_ORG_raw.head()
# Out:
#                                                   id reference  \
# 0  UHJvcG9zYWw6NjllZDU1NzItMWUyMS0xMWU5LTk0ZDItZm...       4-3
# 1  UHJvcG9zYWw6NzlmMGY3YjItMWUyMS0xMWU5LTk0ZDItZm...       4-4
# 2  UHJvcG9zYWw6OTgzNTA5ZGEtMWUyMS0xMWU5LTk0ZDItZm...       4-5
# 3  UHJvcG9zYWw6YjllYjgwMmQtMWUyMS0xMWU5LTk0ZDItZm...       4-6
# 4  UHJvcG9zYWw6ZTYyYjBhY2YtMWUyMS0xMWU5LTk0ZDItZm...       4-7
#
#                                                title            createdAt  \
# 0                                      Les avantages  2019-01-22 09:40:47
# 1                       suppression des départements  2019-01-22 09:41:14
# 2                                          L'égalité  2019-01-22 09:42:04
# 3                               Suppression du Sénat  2019-01-22 09:43:01
# 4  Réformer la justice familiale et établir la pr...  2019-01-22 09:44:15
#
#            publishedAt updatedAt  trashed trashedStatus  \
# 0  2019-01-22 09:40:47       NaN    False           NaN
# 1  2019-01-22 09:41:14       NaN    False           NaN
# 2  2019-01-22 09:42:04       NaN    False           NaN
# 3  2019-01-22 09:43:01       NaN    False           NaN
# 4  2019-01-22 09:44:15       NaN    False           NaN
#
#                                             authorId           authorType  \
# 0  VXNlcjo4Mjc4NzQxYS0xZTFkLTExZTktOTRkMi1mYTE2M2...  Citoyen / Citoyenne
# 1  VXNlcjo3ZTVjYTUwMi0xZDZlLTExZTktOTRkMi1mYTE2M2...  Citoyen / Citoyenne
# 2  VXNlcjo4Mjc4NzQxYS0xZTFkLTExZTktOTRkMi1mYTE2M2...  Citoyen / Citoyenne
# 3  VXNlcjpkM2IzYzU5Ni0xZDZhLTExZTktOTRkMi1mYTE2M2...  Citoyen / Citoyenne
# 4  VXNlcjowYjNkNDQ0Yy0xY2YzLTExZTktOTRkMi1mYTE2M2...  Citoyen / Citoyenne
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    QUXVlc3Rpb246MTk0 - Si vous avez été amené à préparer votre retraite, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MTk1 - Si vous avez été amené à demander un remboursement de soins de santé, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MTk2 - Si vous avez été amené à faire une demande d'aide pour une situation de handicap, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MTk4 - Si vous avez été amené à créer une entreprise, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MTk5 - Si vous avez été amené à recruter du personnel, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MjAw - Si vous avez été amené à former du personnel, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MjAx - Si vous avez été amené à rémunérer du personnel, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MjAy - Si vous avez été amené à mettre fin à votre activité, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MjAz - Si vous avez été amené à recruter une personne portant un handicap, pouvez-vous indiquer les éléments de satisfaction et/ou les difficultés rencontrés en précisant, pour chaque point, l'administration concernée :  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   QUXVlc3Rpb246MTg5 - Y a-t-il d'autres points sur l'organisation de l'Etat et des services publics sur lesquels vous souhaiteriez vous exprimer ?
# 0  Les anciens Présidents, anciens membres du gou...
# 1                                                NaN
# 2  Un salarié qui est logé par son employeur ; le...
# 3                                                NaN
# 4  Il est nécessaire de réformer  la justice fami...
#
# [5 rows x 44 columns]

# %%
def keep_popular_hashtags_by_question(dataframe):
    allowed_categories_gda = []
    print(dataframe['id_gda'].unique())
    for question in dataframe['id_gda'].unique():
        allowed_categories_tuples = Counter(dataframe[dataframe['id_gda'] == question]['Categorie']).most_common(20)
        allowed_categories_gda += [(question, element[0], element[1]) for element in allowed_categories_tuples]
    for question in dataframe['id_elf'].unique():    
        allowed_categories_tuples = Counter(dataframe[dataframe['id_elf'] == question]['Categorie']).most_common(20)
        allowed_categories = [element[0] for element in allowed_categories_tuples]
        dataframe = dataframe[(dataframe['id_elf'] != 'question') | (dataframe['Categorie'].isin(allowed_categories))]
    return dataframe, allowed_categories_gda

def process_LGD_dataset(raw_dataframe):
    """
    """
    answers_annotees = pd.read_csv('raw/actions.csv', encoding="utf-8").rename(columns={'Contribution': 'reference'})
    print(raw_dataframe.shape)
    raw_dataframe = pd.merge(answers_annotees, raw_dataframe, on='reference')
    if raw_dataframe.shape[0] == 0:
        print("Empty records when matching on annotations")
        return None
    
    questions_dictionary = pd.read_csv('raw/match_questions_ELF_LGA.csv', header=0)
    raw_dataframe = pd.merge(raw_dataframe, questions_dictionary, left_on='Question', right_on='id_gda')
    print(raw_dataframe.shape)

    gda_dictionary = pd.read_csv('raw/matching_gda_id1_id2.csv', header=0)
    raw_dataframe = pd.merge(raw_dataframe, gda_dictionary, left_on='id_gda', right_on='id1_gda')
    print(raw_dataframe.shape)
    
    raw_dataframe["corpus"] = None
    
    for index, row in raw_dataframe.iterrows():
        raw_dataframe.at[index,'corpus'] = raw_dataframe.loc[index][raw_dataframe.filter(like=row['id2_gda']).columns[0]]

    raw_dataframe = raw_dataframe[['reference', 'id_elf', 'corpus', 'Categorie', 'Annotateur', 'id_gda']]
    
    removed_categories = ['Z Autres', 'Sans réponse / Hors sujet / Inclassable']
    raw_dataframe = raw_dataframe[~raw_dataframe['Categorie'].isin(removed_categories)]
    print(raw_dataframe.shape)
    
    raw_dataframe, allowed_categories_gda = keep_popular_hashtags_by_question(raw_dataframe)
    print(raw_dataframe.shape)
    
    raw_dataframe = pd.DataFrame({'count' : raw_dataframe.groupby( ['reference', 'Categorie', 'corpus', 'id_elf'] ).apply(lambda x: x.Annotateur.nunique())}).reset_index()
    print(raw_dataframe.shape)
    
    return raw_dataframe.rename(columns={'reference': 'contribution', 'corpus': 'answer', 'Categorie': 'target', 'id_elf' : 'question'}), allowed_categories_gda

# %%
answers_grand_debat_GDA_FDP, allowed_categories_gda_FDP = process_LGD_dataset(answers_grand_debat_FDP_raw)
answers_grand_debat_GDA_ORG, allowed_categories_gda_ORG = process_LGD_dataset(answers_grand_debat_ORG_raw)
answers_grand_debat_GDA_LTE, allowed_categories_gda_LTE = process_LGD_dataset(answers_grand_debat_LTE_raw)
answers_grand_debat_GDA_DEC, allowed_categories_gda_DEC = process_LGD_dataset(answers_grand_debat_DEC_raw)
# Out:
# (302698, 24)
# (23033, 26)
# (23033, 28)
# (18943, 6)
# [162 163]
# (18943, 6)
# (8857, 5)
# (0, 49)
# (0, 51)
# (0, 53)
# (0, 6)
# []
# (0, 6)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-4f2e5ed5a49b> in <module>
#       1 answers_grand_debat_GDA_FDP, allowed_categories_gda_FDP = process_LGD_dataset(answers_grand_debat_FDP_raw)
# ----> 2 answers_grand_debat_GDA_ORG, allowed_categories_gda_ORG = process_LGD_dataset(answers_grand_debat_ORG_raw)
#       3 answers_grand_debat_GDA_LTE, allowed_categories_gda_LTE = process_LGD_dataset(answers_grand_debat_LTE_raw)
#       4 answers_grand_debat_GDA_DEC, allowed_categories_gda_DEC = process_LGD_dataset(answers_grand_debat_DEC_raw)
#
# <ipython-input-118-90769b4c43c6> in process_LGD_dataset(raw_dataframe)
#      40     print(raw_dataframe.shape)
#      41
# ---> 42     raw_dataframe = pd.DataFrame({'count' : raw_dataframe.groupby( ['reference', 'Categorie', 'corpus', 'id_elf'] ).apply(lambda x: x.Annotateur.nunique())}).reset_index()
#      43     print(raw_dataframe.shape)
#      44
#
# /anaconda3/envs/elfrance/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     389                                  dtype=dtype, copy=copy)
#     390         elif isinstance(data, dict):
# --> 391             mgr = init_dict(data, index, columns, dtype=dtype)
#     392         elif isinstance(data, ma.MaskedArray):
#     393             import numpy.ma.mrecords as mrecords
#
# /anaconda3/envs/elfrance/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# /anaconda3/envs/elfrance/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# /anaconda3/envs/elfrance/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     306
#     307         if not indexes and not raw_lengths:
# --> 308             raise ValueError('If using all scalar values, you must pass'
#     309                              ' an index')
#     310
#
# ValueError: If using all scalar values, you must pass an index

# %%
answers_grand_debat_GDA = pd.concat([answers_grand_debat_GDA_FDP, answers_grand_debat_GDA_DEC, answers_grand_debat_GDA_ORG, answers_grand_debat_GDA_LTE])
answers_grand_debat_GDA['source'] = 'GDA'

# %%
answers_grand_debat_ELF = pd.read_csv("preprocessed/elf_tags_sample.csv", sep=";").rename(columns={'reference': 'contribution', 'corpus': 'answer', 'tag': 'target', 'id_elf' : 'question'})
answers_grand_debat_ELF['source'] = 'ELF'

# %%
answers_grand_debat_ELF.head()
# Out:
#   contribution                                            target  \
# 0       37 240  Le peuple pas responsable du problème écologique
# 1       12 970                              Etre plus à l'écoute
# 2       12 970                              Plus de transparence
# 3       13 210          Incitations financières au lieu de taxes
# 4       13 210             Développer les énergies renouvelables
#
#                                               answer question  count source
# 0  Stopper toutes ces taxes et donner une autre i...     TE13      1    ELF
# 1  Avoir des représentants actif qui remontent et...     OE11      1    ELF
# 2  Avoir des représentants actif qui remontent et...     OE11      1    ELF
# 3  Il faudrait pousser la création de beaucoup pl...     TE13      1    ELF
# 4  Il faudrait pousser la création de beaucoup pl...     TE13      1    ELF

# %%
answers_grand_debat = pd.concat([answers_grand_debat_ELF, answers_grand_debat_GDA])
answers_grand_debat.to_csv('preprocessed/reponses_annotees_multilabel.csv', sep='\t', encoding='utf-8')

# %%
answers_grand_debat.head()
# Out:
#   contribution                                            target  \
# 0       37 240  Le peuple pas responsable du problème écologique
# 1       12 970                              Etre plus à l'écoute
# 2       12 970                              Plus de transparence
# 3       13 210          Incitations financières au lieu de taxes
# 4       13 210             Développer les énergies renouvelables
#
#                                               answer question  count source
# 0  Stopper toutes ces taxes et donner une autre i...     TE13      1    ELF
# 1  Avoir des représentants actif qui remontent et...     OE11      1    ELF
# 2  Avoir des représentants actif qui remontent et...     OE11      1    ELF
# 3  Il faudrait pousser la création de beaucoup pl...     TE13      1    ELF
# 4  Il faudrait pousser la création de beaucoup pl...     TE13      1    ELF

# %%
answers_grand_debat_sample = answers_grand_debat[['question', 'answer', 'target']][0:10]
answers_grand_debat_sample = answers_grand_debat_sample
answers_grand_debat_sample.to_json(orient = "records")
# Out:
# '[{"question":"TE13","answer":"Stopper toutes ces taxes et donner une autre image des verts qui ne pensent qu\\u2019\\u00e0 leurs int\\u00e9r\\u00eats \\u00e9lectoraux et personnels et culpabilisent les gens !!","target":"Le peuple pas responsable du probl\\u00e8me \\u00e9cologique"},{"question":"OE11","answer":"Avoir des repr\\u00e9sentants actif qui remontent et traite les probl\\u00e8mes en lieu et place en arr\\u00eatant de tergiverser.","target":"Etre plus \\u00e0 l\'\\u00e9coute"},{"question":"OE11","answer":"Avoir des repr\\u00e9sentants actif qui remontent et traite les probl\\u00e8mes en lieu et place en arr\\u00eatant de tergiverser.","target":"Plus de transparence"},{"question":"TE13","answer":"Il faudrait pousser la cr\\u00e9ation de beaucoup plus de murs v\\u00e9g\\u00e9tale dans les villes. Par exemples, tout les nouveaux b\\u00e2timents en ville devrait int\\u00e9grer des \\u00e9l\\u00e9ments \\u00e9cologique comme des des murs v\\u00e9g\\u00e9tale, des puits de lumi\\u00e8res, des panneaux solaires etc etc etc (soit par une exon\\u00e9ration de taxe, soit par des taxes en plus si non respect\\u00e9","target":"Incitations financi\\u00e8res au lieu de taxes"},{"question":"TE13","answer":"Il faudrait pousser la cr\\u00e9ation de beaucoup plus de murs v\\u00e9g\\u00e9tale dans les villes. Par exemples, tout les nouveaux b\\u00e2timents en ville devrait int\\u00e9grer des \\u00e9l\\u00e9ments \\u00e9cologique comme des des murs v\\u00e9g\\u00e9tale, des puits de lumi\\u00e8res, des panneaux solaires etc etc etc (soit par une exon\\u00e9ration de taxe, soit par des taxes en plus si non respect\\u00e9","target":"D\\u00e9velopper les \\u00e9nergies renouvelables"},{"question":"OE11","answer":"Cr\\u00e9\\u00e9 un r\\u00e9seau plus important, avec des agents mobile par exemple dans plusieur commune, notamment les plus \\u00e9loign\\u00e9, combler les d\\u00e9sert administratif souvent peuple des personnes les plus fragile","target":"Services m\\u00e9dicaux dans les zones rurales"},{"question":"OE11","answer":"Cr\\u00e9\\u00e9 un r\\u00e9seau plus important, avec des agents mobile par exemple dans plusieur commune, notamment les plus \\u00e9loign\\u00e9, combler les d\\u00e9sert administratif souvent peuple des personnes les plus fragile","target":"Simplification d\\u00e9marche administratives"},{"question":"OE11","answer":"Cr\\u00e9\\u00e9 un r\\u00e9seau plus important, avec des agents mobile par exemple dans plusieur commune, notamment les plus \\u00e9loign\\u00e9, combler les d\\u00e9sert administratif souvent peuple des personnes les plus fragile","target":"Plateforme unique service publique et maison de services publics"},{"question":"TE13","answer":"taxer les pollueurs, arr\\u00eater le nucl\\u00e9aire, d\\u00e9velopper les \\u00e9nergies renouvelables","target":"Taxe sur les plus gros pollueurs"},{"question":"TE13","answer":"taxer les pollueurs, arr\\u00eater le nucl\\u00e9aire, d\\u00e9velopper les \\u00e9nergies renouvelables","target":"Arr\\u00eater le nucl\\u00e9aire"}]'
