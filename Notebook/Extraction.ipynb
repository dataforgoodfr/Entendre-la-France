# %%
import pandas as pd

# %%
df = pd.read_csv("./../raw/actions.csv")

# %%
df.head()
# Out:
#    Debat Contribution  Question                                Categorie  \
# 0      1          1-8       107  Sans réponse / Hors sujet / Inclassable
# 1      1          1-8       107  Sans réponse / Hors sujet / Inclassable
# 2      1          1-8       107  Sans réponse / Hors sujet / Inclassable
# 3      1         1-15       107               Président de la République
# 4      1         1-15       107               Président de la République
#
#    Annotateur     Poids
# 0         513  1.451059
# 1           1  1.451059
# 2         406  1.451059
# 3         406  1.543980
# 4           1  1.543980

# %%
df[df.Annotateur==513]
# Out:
#         Debat Contribution  Question                                Categorie  \
# 0           1          1-8       107  Sans réponse / Hors sujet / Inclassable
# 5           1         1-15       107               Président de la République
# 7           1         1-20       107                       Maires et communes
# 15          1         1-42       107                              A Aucun élu
# 20          1         1-43       107                              A Aucun élu
# 25          1         1-55       107                   A Moi-même ou personne
# 28          1         1-65       107                              A Aucun élu
# 33          1         1-70       107                              A Aucun élu
# 39          1         1-72       107                       Maires et communes
# 41          1         1-78       107                       Députés, assemblée
# 56          1         1-92       107                              A Aucun élu
# ...
